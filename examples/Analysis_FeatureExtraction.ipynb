# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas
import pathlib
from IPython.display import display

import bletl
import bletl_analysis
from bletl_analysis import features

# %% [markdown]
# ### Parse the raw data file

# %%
filepath = pathlib.Path(r'..\bletl\tests\data\BL1\NT_1200rpm_30C_DO-GFP75-pH-BS10_12min_20171221_121339.csv')
bldata = bletl.parse(filepath, lot_number=1515, temp=30)

# %% [markdown]
# # Feature Extraction

# %% [markdown]
# Create a map of Filtersets that you want to extract with a list of Extractors.

# %%
extractors = {
    "BS10" : [features.BSFeatureExtractor, features.StatisticalFeatureExtractor, features.TSFreshExtractor],
    "pH" : [features.pHFeatureExtractor, features.StatisticalFeatureExtractor, features.TSFreshExtractor],
    "DO" : [features.DOFeatureExtractor, features.StatisticalFeatureExtractor, features.TSFreshExtractor],
}
last_cycles = {
    "A01" : 20,
    "B01" : 50
}

# %% [markdown]
# Start feature extraction with bldata, extractors and last_cycles (optional).

# %%
extracted_features = features.from_bldata(bldata=bldata, extractors=extractors, last_cycles=last_cycles)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='48' class='' max='48' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [48/48 02:12<00:00]
#     </div>
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.9s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    1.1s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    1.2s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    1.1s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    1.3s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    1.1s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.6s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.5s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.4s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.6s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=6)]: Batch computation too fast (0.0534s.) Setting batch_size=2.
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.0s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.4s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.3s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.5s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.4s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.3s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.4s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.7s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.5s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=6)]: Batch computation too fast (0.0406s.) Setting batch_size=2.
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.0s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.3s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.4s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.5s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.5s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    1.1s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.6s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.9s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=6)]: Batch computation too fast (0.0459s.) Setting batch_size=2.
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.0s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.4s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.4s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.5s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.4s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.5s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.8s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.6s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=6)]: Batch computation too fast (0.0404s.) Setting batch_size=2.
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.0s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.5s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.4s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.5s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.5s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.7s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.7s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.5s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.4s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.4s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.4s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.4s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:    0.7s finished
# Feature Extraction: 100%|██████████████████████████████████████████████████████████████| 12/12 [00:01<00:00,  7.86it/s]
# Feature Extraction: 100%|██████████████████████████████████████████████████████████████| 12/12 [00:01<00:00,  8.04it/s]
# Feature Extraction: 100%|██████████████████████████████████████████████████████████████| 12/12 [00:01<00:00,  8.09it/s]

# %% [markdown]
# ### Show extracted data

# %%
display(extracted_features.head())
# Out:
#      BS10__inflection_point_t  BS10__inflection_point_y  BS10__mue_median  \
# A01                 15.589340                   3.93831          2.884133
# A02                114.049172                  22.02844          0.512498
# A03                158.104604                  22.02891          0.013299
# A04                148.610349                  21.13505          0.096564
# A05                129.941607                  16.78825          0.367593
#
#       BS10__max  BS10__mean  BS10__median  BS10__min  BS10__span  \
# A01   15.589340   13.236223     12.942862  11.786574    3.802765
# A02  114.049172   43.789110     37.938058  10.662952  103.386220
# A03  158.104604   52.730195     42.885822  11.259160  146.845445
# A04  169.490066   52.947190     40.735298  11.072086  158.417980
# A05  181.684883   68.253222     43.571497  11.010531  170.674352
#
#      BS10__stan_dev  BS10__time_max  ...  \
# A01        1.135330         3.93831  ...
# A02       27.608253        22.02844  ...
# A03       39.335875        22.02891  ...
# A04       41.251284        22.02937  ...
# A05       59.208052        22.02988  ...
#
#      DO_x__symmetry_looking__r_0.9500000000000001  \
# A01                                           0.0
# A02                                           0.0
# A03                                           0.0
# A04                                           0.0
# A05                                           0.0
#
#      DO_x__time_reversal_asymmetry_statistic__lag_1  \
# A01                                             0.0
# A02                                             0.0
# A03                                             0.0
# A04                                             0.0
# A05                                             0.0
#
#      DO_x__time_reversal_asymmetry_statistic__lag_2  \
# A01                                             0.0
# A02                                             0.0
# A03                                             0.0
# A04                                             0.0
# A05                                             0.0
#
#      DO_x__time_reversal_asymmetry_statistic__lag_3  \
# A01                                             0.0
# A02                                             0.0
# A03                                             0.0
# A04                                             0.0
# A05                                             0.0
#
#      DO_x__value_count__value_-1  DO_x__value_count__value_0  \
# A01                          0.0                         0.0
# A02                          0.0                         0.0
# A03                          0.0                         0.0
# A04                          0.0                         0.0
# A05                          0.0                         0.0
#
#      DO_x__value_count__value_1  DO_x__variance  \
# A01                         0.0             0.0
# A02                         0.0             0.0
# A03                         0.0             0.0
# A04                         0.0             0.0
# A05                         0.0             0.0
#
#      DO_x__variance_larger_than_standard_deviation  \
# A01                                            0.0
# A02                                            0.0
# A03                                            0.0
# A04                                            0.0
# A05                                            0.0
#
#      DO_x__variation_coefficient
# A01                          0.0
# A02                          0.0
# A03                          0.0
# A04                          0.0
# A05                          0.0
#
# [5 rows x 2319 columns]
